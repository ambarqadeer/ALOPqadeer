# %% [markdown]
# Imports

# %%
import sp
from astropy.io import ascii
import time
import ccdproc as ccdp
from astropy.nddata import CCDData
import numpy as np
import glob
import itertools
from astropy.table import Table
from astropy import table
import Logs
from astropy.convolution import convolve, Box1DKernel
import matplotlib.pyplot as plt

# %% [markdown]
# Photometry

# %%
science=ccdp.ImageFileCollection('Final_Science/median')

# sciencelist=glob.glob('Corrected_Science/r*fit')
#ascii.write(sc,'sc_summary.csv',format='csv',overwrite=True)
#found=Table(names=('fname','x','y','sh','ro'),dtype=('str','float32','float32','float32','float32'))
trackerf=[]
trackera=[]
start=time.time()
for imsd,imsn in science.data(return_fname=True):
    print('\nassessing',imsn)
    try:
        x,y,flux,sh,ro=sp.find(imsd,hmin=3000,fwhm=17)
        if len(x) == 2:
            for i in range(len(x)):
                trackerf.append([imsn,x[i],y[i],sh[i],ro[i]])
            flux,eflux,sky,skerr=sp.aper(imsd,x,y,phpadu=2.9,apr=[5],skyrad=[15,20],flux=True)
            trackera.append([imsn,flux[0][0],flux[1][0],sky[0],sky[1],eflux[0][0],eflux[1][0]])
            print(imsn,'flux calculated')
        elif len(x) != 2:
            print('skipping',imsn,'since it did not return exactly 2 star coordinates')

    except Exception as e:
        print(imsn,'did not meet sharpness or roundness criteria')
        print(e)
    


tf=np.reshape(trackerf,(-1,5))
ta=np.reshape(trackera,(-1,7))
print(time.time()-start)
foundf=Table(tf,names=('fname','x','y','sh','ro'),dtype=('str','float64','float64','float64','float64'))
fluxt=Table(ta,names=('fname','fluxcalib','fluxtarget','skycalib','skytarget','fluxerrcalib','fluxerrtarget')
            ,dtype=('str','float64','float64','float64','float64','float64','float64'))
ascii.write(foundf,'stars.csv',format='csv',overwrite=True)
ascii.write(fluxt,'fluxes.csv',format='csv',overwrite=True)
# Out:
# assessing r1382286.fit
# x, y in pixels, flux and sky in ADU
# =======================================
# aperture radius is 5 pixels
# =======================================
# x		 y		 flux +- fluxerr 		sky +- skyerr
# 656.7798168230659 	 341.40056314751246 	 1648475.4384725841 +- 1043.587617591276 	 36.06361645946924 +- 79.58041064058203
# 1049.820944938087 	 1042.1630725831233 	 1170536.109071539 +- 792.5964535509203 	 30.85885367882036 +- 52.266213110759836
# r1382286.fit flux calculated
# assessing r1382287.fit
# skipping r1382287.fit since it did not return exactly 2 star coordinates
# assessing r1382288.fit
# WARNING!!! There is no source meeting the 'sharpness' criterion.
# r1382288.fit did not meet sharpness or roundness criteria
# cannot unpack non-iterable NoneType object
# assessing r1382289.fit
# x, y in pixels, flux and sky in ADU
# =======================================
# aperture radius is 5 pixels
# =======================================
# x		 y		 flux +- fluxerr 		sky +- skyerr
# 658.5510733469569 	 340.1607964486932 	 1892595.0752970558 +- 942.5417788814677 	 34.23317771579201 +- 53.55252673113116
# 1051.592608035899 	 1040.8981152545043 	 1332076.066637035 +- 773.3752231394603 	 25.31470993986551 +- 41.08575998346673
# r1382289.fit flux calculated
# assessing r1382290.fit
# skipping r1382290.fit since it did not return exactly 2 star coordinates
# assessing r1382291.fit
# WARNING!!! There is no source meeting the 'sharpness' criterion.
# r1382291.fit did not meet sharpness or roundness criteria
# cannot unpack non-iterable NoneType object
# assessing r1382292.fit
# x, y in pixels, flux and sky in ADU
# =======================================
# aperture radius is 5 pixels
# =======================================
# x		 y		 flux +- fluxerr 		sky +- skyerr
# 659.2661696525123 	 339.71717861019334 	 1859573.091989694 +- 1108.4216128651908 	 42.06519973404812 +- 84.5266983553938
# 1052.3610097355554 	 1040.4979503480436 	 1323919.767206966 +- 859.1991992906947 	 34.54205134513677 +- 58.53723144552195
# r1382292.fit flux calculated
# assessing r1382293.fit
# skipping r1382293.fit since it did not return exactly 2 star coordinates
# assessing r1382294.fit
# x, y in pixels, flux and sky in ADU
# =======================================
# aperture radius is 5 pixels
# =======================================
# x		 y		 flux +- fluxerr 		sky +- skyerr
# 658.8179192562311 	 339.54934897515966 	 1921678.3376038966 +- 1076.4332491076532 	 36.357374632919566 +- 77.67957441672336
# 1051.936949485071 	 1040.4084235024802 	 1344845.9798580722 +- 831.6476082875215 	 30.02110889585873 +- 52.651334901969406
# r1382294.fit flux calculated
# assessing r1382295.fit
# x, y in pixels, flux and sky in ADU
# =======================================
# aperture radius is 5 pixels
# =======================================
# x		 y		 flux +- fluxerr 		sky +- skyerr
#
fit
# x, y in pixels, flux and sky in ADU
# =======================================
# aperture radius is 5 pixels
# =======================================
# x		 y		 flux +- fluxerr 		sky +- skyerr
# 671.1229986520052 	 331.3232497929736 	 1221632.1458712209 +- 961.1345347564938 	 28.27140810297564 +- 78.184222742194
# 1064.1425439689226 	 1032.0754407816235 	 812181.8666206056 +- 727.0682797220353 	 26.02862710821387 +- 54.98697815451536
# r1382331.fit flux calculated
# assessing r1382332.fit
# WARNING!!! There is no source meeting the 'sharpness' criterion.
# r1382332.fit did not meet sharpness or roundness criteria
# cannot unpack non-iterable NoneType object
# assessing r1382333.fit
# WARNING!!! There is no source meeting the 'sharpness' criterion.
# r1382333.fit did not meet sharpness or roundness criteria
# cannot unpack non-iterable NoneType object
# assessing r1382334.fit
# WARNING!!! There is no source meeting the 'sharpness' criterion.
# r1382334.fit did not meet sharpness or roundness criteria
# cannot unpack non-iterable NoneType object
# assessing r1382335.fit
# x, y in pixels, flux and sky in ADU
# =======================================
# aperture radius is 5 pixels
# =======================================
# x		 y		 flux +- fluxerr 		sky +- skyerr
# 671.2235556933922 	 330.03104890150837 	 1134136.8356729075 +- 840.3076532304008 	 42.21264117849603 +- 61.904036123192235
# 1064.2133342965433 	 1030.8150994623336 	 733078.7981027489 +- 659.8453860902824 	 29.709713558648758 +- 47.130474549189806
# r1382335.fit flux calculated
# assessing r1382336.fit
# skipping r1382336.fit since it did not return exactly 2 star coordinates
# assessing r1382337.fit
# WARNING!!! There is no source meeting the 'sharpness' criterion.
# r1382337.fit did not meet sharpness or roundness criteria
# cannot unpack non-iterable NoneType object
# assessing r1382338.fit
# WARNING!!! There is no source meeting the 'sharpness' criterion.
# r1382338.fit did not meet sharpness or roundness criteria
# cannot unpack non-iterable NoneType object
# assessing r1382339.fit
# skipping r1382339.fit since it did not return exactly 2 star coordinates
# assessing r1382340.fit
# skipping r1382340.fit since it did not return exactly 2 star coordinates
# assessing r1382341.fit
# WARNING!!! There is no source meeting the 'sharpness' criterion.
# r1382341.fit did not meet sharpness or roundness criteria
# cannot unpack non-iterable NoneType object
# assessing r1382342.fit
# x, y in pixels, flux and sky in ADU
# =======================================
# aperture radius is 5 pixels
# =======================================
# x		 y		 flux +- fluxerr 		sky +- skyerr
# 671.1713117009683 	 333.01666465809507 	 1198325.005340308 +- 933.2180554546485 	 39.05304093842966 +- 74.61403615055292
# 1064.122972022206 	 1033.7132901860232 	 789156.9139044615 +- 716.2696224981597 	 31.504586891483456 +- 54.13460611374162
# r1382342.fit flux calculated
# assessing r1382343.fit
# skipping r1382343.fit since it did not return exactly 2 star coordinates
# assessing r1382344.fit
# x, y in pixels, flux and sky in ADU
# =======================================
# aperture radius is 5 pixels
# =======================================
# x		 y		 flux +- fluxerr 		sky +- skyerr
# 671.1786249040495 	 331.44084131075556 	 1092611.8965610582 +- 951.8108265215453 	 36.975506377658206 +- 80.23087706878859
# 1064.2243561022942 	 1032.2070239869513 	 745237.1294349403 +- 725.1119915011686 	 29.577812973728953 +- 57.18226233839466
# r1382344.fit flux calculated
# assessing r1382345.fit
# skipping r1382345.fit since it did not return exactly 2 star coordinates
# assessing r1382346.fit
# skipping r1382346.fit since it did not return exactly 2 star coordinates
# assessing r1382347.fit
# x, y in pixels, flux and sky in ADU
# =======================================
# aperture radius is 5 pixels
# =======================================
# x		 y		 flux +- fluxerr 		sky +- skyerr
# 672.1314152981861 	 331.44386014070756 	 1251021.081602846 +- 933.132654696523 	 38.83131910622333 +- 73.10459371718996
# 1065.0513648146057 	 1031.8426076596886 	 826500.442503056 +- 734.9841599987905 	 26.58709967549882 +- 55.71614134291383
# r1382347.fit flux calculated
# assessing r1382348.fit
# skipping r1382348.fit since it did not return exactly 2 star coordinates
# assessing r1382349.fit
# skipping r1382349.fit since it did not return exactly 2 star coordinates
# assessing r1382350.fit
# x, y in pixels, flux and sky in ADU
# =======================================
# aperture radius is 5 pixels
# =======================================
# x		 y		 flux +- fluxerr 		sky +- skyerr
# 673.0774584024408 	 333.47000379770816 	 1150379.6438382477 +- 990.4297198741515 	 38.52766859723687 +- 84.3034918699033
# 1066.0876599654748 	 1033.900176878887 	 784079.6963852517 +- 752.2980221895963 	 29.56223249766208 +- 59.96210806166773
# r1382350.fit flux calculated
# assessing r1382351.fit
# x, y in pixels, flux and sky in ADU
# =======================================
# aperture radius is 5 pixels
# =======================================
# x		 y		 flux +- fluxerr 		sky +- skyerr
# 672.4076415175819 	 333.17958008014364 	 1128914.1813305765 +- 930.900626465152 	 35.73015537615038 +- 76.19612946087376
# 1065.2508321512073 	 1033.639836032177 	 757657.9814822141 +- 721.6602037108245 	 26.322592172310124 +- 56.18687620805378
# r1382351.fit flux calculated
# assessing r1382352.fit
# x, y in pixels, flux and sky in ADU
# =======================================
# aperture radius is 5 pixels
# =======================================
# x		 y		 flux +- fluxerr 		sky +- skyerr
# 673.4126779195271 	 334.11006163033625 	 1154103.2159409863 +- 860.3095830741378 	 22.08220216660154 +- 64.51456345217154
# 1066.4923161895724 	 1034.7221777365069 	 762025.3934916088 +- 642.7090493772018 	 17.755984946420185 +- 42.759218336639016
# r1382352.fit flux calculated
# assessing r1382353.fit
# WARNING!!! There is no source meeting the 'sharpness' criterion.
# r1382353.fit did not meet sharpness or roundness criteria
# cannot unpack non-iterable NoneType object
# assessing r1382354.fit
# x, y in pixels, flux and sky in ADU
# =======================================
# aperture radius is 5 pixels
# =======================================
# x		 y		 flux +- fluxerr 		sky +- skyerr
# 673.700699960347 	 333.44683157517204 	 1178208.314786329 +- 922.3136963449651 	 38.63213626839243 +- 73.52219901431785
# 1066.749893574015 	 1034.222570837505 	 773187.6285856625 +- 676.6370871959641 	 30.086166752414215 +- 48.22891893361006
# r1382354.fit flux calculated
# assessing r1382355.fit
# WARNING!!! There is no source meeting the 'sharpness' criterion.
# r1382355.fit did not meet sharpness or roundness criteria
# cannot unpack non-iterable NoneType object
# assessing r1382356.fit
# WARNING!!! There is no source meeting the 'sharpness' criterion.
# r1382356.fit did not meet sharpness or roundness criteria
# cannot unpack non-iterable NoneType object
# assessing r1382357.fit
# WARNING!!! There is no source meeting the 'sharpness' criterion.
# r1382357.fit did not meet sharpness or roundness criteria
# cannot unpack non-iterable NoneType object
# assessing r1382358.fit
# skipping r1382358.fit since it did not return exactly 2 star coordinates
# assessing r1382359.fit
# skipping r1382359.fit since it did not return exactly 2 star coordinates
# assessing r1382360.fit
# WARNING!!! There is no source meeting the 'sharpness' criterion.
# r1382360.fit did not meet sharpness or roundness criteria
# cannot unpack non-iterable NoneType object
# assessing r1382361.fit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-6899436f977b> in <module>
#      10     print('assessing',imsn)
#      11     try:
# ---> 12         x,y,flux,sh,ro=sp.find(imsd,hmin=3000,fwhm=17)
#      13         if len(x) == 2:
#      14             for i in range(len(x)):
#
# ~\ALOPqadeer\sp.py in find(image, hmin, fwhm, nsigma, roundlim, sharplim)
#     974         return None
#     975     offsetsx = numpy.resize(goodx-middle,(nfound,nmask)) # a (nfound, nmask) array of good positions in the mask, mask coordinate
# --> 976     offsetsx = indx + offsetsx.T # a (nmask, nfound) array of positions in the mask for each candidate, image coordinate
#     977     offsetsy = numpy.resize(goody-middle,(nfound,nmask)) # a (nfound, nmask) array of good positions in the mask, mask coordinate
#     978     offsetsy = indy + offsetsy.T # a (nmask, nfound) array of positions in the mask for each candidate, image coordinate
#
# KeyboardInterrupt:

# %% [markdown]
# Get logs

# %%
log1=Logs.parse_logfile('HD115709/log_files/run_log_20180428.int')
log2=Logs.parse_logfile('HD115709/log_files/run_log_20180430.int')

log1t=Table(list(log1['Observations'].values()),names=tuple(log1['Observations'].keys()))

log2t=Table(list(log2['Observations'].values()),names=tuple(log2['Observations'].keys()))


# logc=table.vstack([log1t,log2t])

# %% [markdown]
# Data manipulation

# %%
# fluxt=ascii.read('fluxes.csv')


c=[]
for i, val in enumerate(fluxt['fname']):
    c.append(int(val[1:8]))

fluxt['Run']=c

final1=table.join(fluxt,log1t,keys='Run')
final2=table.join(fluxt,log2t,keys='Run')


final1['truefluxcalib']=final1['fluxcalib']/final1['Exptime']
final2['truefluxcalib']=final2['fluxcalib']/final2['Exptime']

final1['truefluxtarget']=final1['fluxtarget']/final1['Exptime']
final2['truefluxtarget']=final2['fluxtarget']/final2['Exptime']

final1['diff']=final1['truefluxcalib']-final1['truefluxtarget']
final2['diff']=final2['truefluxcalib']-final2['truefluxtarget']


final1['relflux']=final1['diff']/np.nanmedian(final1['diff'])
final2['relflux']=final2['diff']/np.nanmedian(final2['diff'])

# %% [markdown]
# Convolve

# %%
final1['smadiff']=convolve(list(final1['relflux']),kernel=Box1DKernel(10),boundary='extend')
final2['smadiff']=convolve(list(final2['relflux']),kernel=Box1DKernel(10),boundary='extend')


ascii.write(final1,'final1.csv',overwrite=True,format='csv')
ascii.write(final2,'final2.csv',overwrite=True,format='csv')

# %% [markdown]
# Plot

# %%
fig, axs=plt.subplots(1,2,figsize=(40,10))
axs[0].scatter(final1['MJD']+2400000.5,final1['smadiff'])
axs[0].ticklabel_format(axis='x',useOffset=True,useLocale=True)
axs[1].scatter(final2['MJD']+2400000.5,final2['smadiff'])
axs[1].ticklabel_format(axis='x',useOffset=True,useLocale=True)
plt.show()
