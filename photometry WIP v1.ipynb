# %%
import sp
from astropy.io import ascii
import time
import ccdproc as ccdp
import numpy as np
import glob
import itertools
from astropy.table import Table

# %%
science=ccdp.ImageFileCollection('Corrected_Science')
sciencelist=glob.glob('Corrected_Science/r*fit')
#ascii.write(sc,'sc_summary.csv',format='csv',overwrite=True)
#found=Table(names=('fname','x','y','sh','ro'),dtype=('str','float32','float32','float32','float32'))
tracker=[]
for imsd,imsn in itertools.islice(science.data(return_fname=True),10):
#    print('assessing',imsn)
    try:
        x,y,flux,sh,ro=spaq.find(imsd,hmin=1000,fwhm=12,sharplim=([-1,1]),roundlim=([-5,5]))
        for i in range(len(x)):
            tracker.append([imsn,x[i],y[i],sh[i],ro[i]])
    except Exception as e:
        print(imsn,'did not meet one of the criteria')
        print(e)
t=np.resize(tracker,(20,5))
print(t)
found=Table(t,names=('fname','x','y','sh','ro'))
ascii.write(found,'stars.csv',format='csv',overwrite=True)
# Out:
# [['r1382286.fit' '655.9639816408721' '340.766994483765'
#   '0.6654910367835108' '0.454448836455425']
#  ['r1382286.fit' '1049.5033401755877' '1041.6055069624565'
#   '0.5586038891753813' '0.46801935883705326']
#  ['r1382287.fit' '658.8241193101842' '338.65342491930323'
#   '0.37958833484439486' '0.049733809728523454']
#  ['r1382287.fit' '1051.8340229302046' '1039.4626893929944'
#   '0.40654656786690646' '0.02903647007128282']
#  ['r1382288.fit' '658.5336114542644' '338.62480647217956'
#   '0.2956395590468099' '0.8019848775683522']
#  ['r1382288.fit' '1051.2044966245498' '1039.7971964240787'
#   '0.1411643014219358' '0.5994806788775151']
#  ['r1382289.fit' '658.7289081628918' '339.7822429488381'
#   '0.26236893417898455' '-0.027366920249954338']
#  ['r1382289.fit' '1051.7486261479444' '1040.1782756469713'
#   '0.41138952355068015' '-0.04933405086671249']
#  ['r1382290.fit' '660.5232352621937' '340.510098565808'
#   '0.41942747042631184' '-0.14876231981909138']
#  ['r1382290.fit' '1053.4719229767616' '1041.3163015764235'
#   '0.45574503221443907' '-0.1916670771978587']
#  ['r1382291.fit' '659.1721676933535' '338.59696783740145'
#   '-0.04167601673803759' '0.42999673040207254']
#  ['r1382291.fit' '1051.8082974181375' '1039.4521652213657'
#   '0.02006954081183183' '0.3427468517067765']
#  ['r1382292.fit' '659.5657575766941' '339.1067302498284'
#   '0.39595997529630944' '0.2278459606494616']
#  ['r1382292.fit' '1052.620098929725' '1039.899873632383'
#   '0.48938936767291685' '0.1282056945999175']
#  ['r1382293.fit' '659.8117037650135' '339.5017533669195'
#   '0.16290854950932843' '-0.454922035660042']
#  ['r1382293.fit' '1052.7794749471052' '1040.0057791803185'
#   '0.6272779610565713' '-0.47905695567491274']
#  ['r1382294.fit' '659.2450869939393' '339.0567336931933'
#   '0.27668245428366184' '0.43371487776047607']
#  ['r1382294.fit' '1052.0448722164224' '1040.1980135093997'
#   '0.3115592460371298' '0.3560816567772413']
#  ['r1382295.fit' '660.6281221586656' '339.0176658103707'
#   '0.5999639903077636' '0.14872372295623917']
#  ['r1382295.fit' '1053.6355626289455' '1039.8142632112404'
#   '0.6583878099692999' '0.07441534064456375']]

# %%
tracker
# Out:
# [['r1382286.fit',
#   655.9639816408721,
#   340.766994483765,
#   0.6654910367835108,
#   0.454448836455425],
#  ['r1382286.fit',
#   1049.5033401755877,
#   1041.6055069624565,
#   0.5586038891753813,
#   0.46801935883705326],
#  ['r1382287.fit',
#   658.8241193101842,
#   338.65342491930323,
#   0.37958833484439486,
#   0.049733809728523454],
#  ['r1382287.fit',
#   1051.8340229302046,
#   1039.4626893929944,
#   0.40654656786690646,
#   0.02903647007128282],
#  ['r1382288.fit',
#   658.5336114542644,
#   338.62480647217956,
#   0.2956395590468099,
#   0.8019848775683522],
#  ['r1382288.fit',
#   1051.2044966245498,
#   1039.7971964240787,
#   0.1411643014219358,
#   0.5994806788775151],
#  ['r1382289.fit',
#   658.7289081628918,
#   339.7822429488381,
#   0.26236893417898455,
#   -0.027366920249954338],
#  ['r1382289.fit',
#   1051.7486261479444,
#   1040.1782756469713,
#   0.41138952355068015,
#   -0.04933405086671249],
#  ['r1382290.fit',
#   660.5232352621937,
#   340.510098565808,
#   0.41942747042631184,
#   -0.14876231981909138],
#  ['r1382290.fit',
#   1053.4719229767616,
#   1041.3163015764235,
#   0.45574503221443907,
#   -0.1916670771978587],
#  ['r1382291.fit',
#   659.1721676933535,
#   338.59696783740145,
#   -0.04167601673803759,
#   0.42999673040207254],
#  ['r1382291.fit',
#   1051.8082974181375,
#   1039.4521652213657,
#   0.02006954081183183,
#   0.3427468517067765],
#  ['r1382292.fit',
#   659.5657575766941,
#   339.1067302498284,
#   0.39595997529630944,
#   0.2278459606494616],
#  ['r1382292.fit',
#   1052.620098929725,
#   1039.899873632383,
#   0.48938936767291685,
#   0.1282056945999175],
#  ['r1382293.fit',
#   659.8117037650135,
#   339.5017533669195,
#   0.16290854950932843,
#   -0.454922035660042],
#  ['r1382293.fit',
#   1052.7794749471052,
#   1040.0057791803185,
#   0.6272779610565713,
#   -0.47905695567491274],
#  ['r1382294.fit',
#   659.2450869939393,
#   339.0567336931933,
#   0.27668245428366184,
#   0.43371487776047607],
#  ['r1382294.fit',
#   1052.0448722164224,
#   1040.1980135093997,
#   0.3115592460371298,
#   0.3560816567772413],
#  ['r1382295.fit',
#   660.6281221586656,
#   339.0176658103707,
#   0.5999639903077636,
#   0.14872372295623917],
#  ['r1382295.fit',
#   1053.6355626289455,
#   1039.8142632112404,
#   0.6583878099692999,
#   0.07441534064456375]]
